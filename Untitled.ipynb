# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
data = pd.read_csv("garments_worker_productivity.csv")
data.head()
# Out:
#        date   quarter  department       day  team  targeted_productivity  \
# 0  1/1/2015  Quarter1      sweing  Thursday     8                   0.80
# 1  1/1/2015  Quarter1  finishing   Thursday     1                   0.75
# 2  1/1/2015  Quarter1      sweing  Thursday    11                   0.80
# 3  1/1/2015  Quarter1      sweing  Thursday    12                   0.80
# 4  1/1/2015  Quarter1      sweing  Thursday     6                   0.80
#
#      smv     wip  over_time  incentive  idle_time  idle_men  \
# 0  26.16  1108.0       7080         98        0.0         0
# 1   3.94     NaN        960          0        0.0         0
# 2  11.41   968.0       3660         50        0.0         0
# 3  11.41   968.0       3660         50        0.0         0
# 4  25.90  1170.0       1920         50        0.0         0
#
#    no_of_style_change  no_of_workers  actual_productivity
# 0                   0           59.0             0.940725
# ...

# %%
data["department"] = data["department"].astype("category")
data["team"] = data["team"].astype("category")

def normal(x):
    if x == "finishing ":
        x = "finishing"
    return x

#data["department"] = data["department"].apply(lambda x: normal(x))

# %%
data["department"].value_counts()
# Out:
# sweing        691
# finishing     257
# finishing     249
# Name: department, dtype: int64

# %%
data["department"] = data["department"].replace("finishing ", "finishing")
data["department"].value_counts()
# Out:
# sweing       691
# finishing    506
# Name: department, dtype: int64

# %%
data["date"] = pd.to_datetime(data["date"])
data["date"]
# Out:
# 0      2015-01-01
# 1      2015-01-01
# 2      2015-01-01
# 3      2015-01-01
# 4      2015-01-01
#           ...
# 1192   2015-03-11
# 1193   2015-03-11
# 1194   2015-03-11
# 1195   2015-03-11
# 1196   2015-03-11
# Name: date, Length: 1197, dtype: datetime64[ns]

# %%
data.head()
# Out:
#         date   quarter department       day team  targeted_productivity  \
# 0 2015-01-01  Quarter1       swei  Thursday    8                   0.80
# 1 2015-01-01  Quarter1     inishi  Thursday    1                   0.75
# 2 2015-01-01  Quarter1       swei  Thursday   11                   0.80
# 3 2015-01-01  Quarter1       swei  Thursday   12                   0.80
# 4 2015-01-01  Quarter1       swei  Thursday    6                   0.80
#
#      smv     wip  over_time  incentive  idle_time  idle_men  \
# 0  26.16  1108.0       7080         98        0.0         0
# 1   3.94     NaN        960          0        0.0         0
# 2  11.41   968.0       3660         50        0.0         0
# 3  11.41   968.0       3660         50        0.0         0
# 4  25.90  1170.0       1920         50        0.0         0
#
#    no_of_style_change  no_of_workers  actual_productivity
# 0                   0           59.0             0.940725
# ...

# %%
sns.relplot(x="incentive", y="targeted_productivity", data=data, kind="scatter")

# %%
sns.catplot(x="team", y="over_time", data=data, kind="box", col="department")

# %%
data["date"].describe(datetime_is_numeric=True)
# Out:
# count                             1197
# mean     2015-02-04 10:56:50.526315776
# min                2015-01-01 00:00:00
# 25%                2015-01-18 00:00:00
# 50%                2015-02-03 00:00:00
# 75%                2015-02-23 00:00:00
# max                2015-03-11 00:00:00
# Name: date, dtype: object

# %%
m = data.groupby(by="date").sum()
m = m.reset_index()

# %%
import plotly.express as px

# %%
x = np.linspace(0,50,100)
y = np.random.randint(0,50,100)
size = np.random.randint(0,10,100)

# %%
plt.figure(figsize=(8,5))
plt.scatter(x,y,s=size*100,alpha=0.3, c=size)
plt.colorbar()
plt.barh(y=20,width=50,alpha=0.2)
# Out:
# <BarContainer object of 1 artists>

# %%
sns.catplot(x="team", y="over_time", data=data,kind="point", capsize=0.1, join=False)
plt.show()

# %%
data["department"].str.strip()
# Out:
# 0          sweing
# 1       finishing
# 2          sweing
# 3          sweing
# 4          sweing
#           ...
# 1192    finishing
# 1193    finishing
# 1194    finishing
# 1195    finishing
# 1196    finishing
# Name: department, Length: 1197, dtype: object

# %%
sns.jointplot(x="no_of_workers", y="actual_productivity",data=data, kind="resid")

# %%
data.columns
# Out:
# Index(['date', 'quarter', 'department', 'day', 'team', 'targeted_productivity',
#        'smv', 'wip', 'over_time', 'incentive', 'idle_time', 'idle_men',
#        'no_of_style_change', 'no_of_workers', 'actual_productivity'],
#       dtype='object')

# %%
df1 = data.groupby(by="day").mean()

# %%
sns.heatmap(data=df1[['targeted_productivity', 'actual_productivity']],annot=True, linewidths=.5)
# Out:
# <AxesSubplot:ylabel='day'>

# %%
sns.histplot(x="actual_productivity",data=data[["actual_productivity", "department"]],kde=True)
plt.show()

# %%
sns.pairplotrplot(data=data)
